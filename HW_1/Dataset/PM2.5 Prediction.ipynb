# %% [markdown]
# # PM2.5 Prediction

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_ori = pd.read_csv(r"train.csv")
# print(data_ori.columns)
PM = data['observation']=='PM2.5'
data_ori1 = data[PM]
data_ori1.drop(['Date', 'stations', 'observation'], axis=1, inplace=True)
series1 = data_ori1.index
series1.dtype = np.uint8
print(series1)
for i in data_ori1.index[0]:
    print(data_ori1.loc[i, :])
# Out:
# d:\python3.5.2\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-908dc455e8c0> in <module>
#       5 data_ori1.drop(['Date', 'stations', 'observation'], axis=1, inplace=True)
#       6 series1 = data_ori1.index
# ----> 7 series1.dtype = np.uint8
#       8 print(series1)
#       9 for i in data_ori1.index[0]:
#
# pandas\_libs\properties.pyx in pandas._libs.properties.CachedProperty.__set__()
#
# AttributeError: Can't set attribute

# %%
ufo = pd.read_csv('ufo.csv')

ufo.drop('City', axis=1, inplace=True)
print(ufo)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...
